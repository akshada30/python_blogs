# %%
import folium

# %%
import pandas as pd

# %%
df = pd.read_csv("world.csv")

# %%
df.drop("Unnamed: 0", axis=1, inplace=True)

# %%
df
# Out:
#       latitude   longitude                    Country      Cases    Deaths  \
# 0    37.090240  -95.712891              United States  2115994.0  117126.0
# 1   -14.235004  -51.925280                     Brazil   850796.0   42791.0
# 2    61.524010  105.318756                     Russia   528964.0    6948.0
# 3    20.593684   78.962880                      India   320922.0    9195.0
# 4    55.378051   -3.435973             United Kingdom   294375.0   41662.0
# ..         ...         ...                        ...        ...       ...
# 189  18.420695  -64.639968     British Virgin Islands        8.0       1.0
# 190  -6.314993  143.955550           Papua New Guinea        8.0       0.0
# 191 -29.609988   28.233608                    Lesotho        4.0       0.0
# 192  18.220554  -63.068615                   Anguilla        3.0       0.0
# 193  46.941936  -56.271110  Saint Pierre and Miquelon        1.0       0.0
#
#      Recoveries
# 0      650279.0
# 1      427610.0
# 2      280050.0
# 3      162379.0
# 4           NaN
# ..          ...
# 189         7.0
# 190         8.0
# 191         2.0
# 192         3.0
# 193         1.0
#
# [194 rows x 6 columns]

# %%
avg = df.Cases.mean()

# %%
map = folium.Map(zoom_start=4)

# %%
df['Cases'].astype(int)
# df['Cases']=df['Cases']/df['Cases'].mean()
for lat, lon, value, name in zip(df['latitude'], df['longitude'], df['Cases'], df['Country']):
    folium.CircleMarker([lat, lon],
                        radius=value/avg,
                        popup = ('<strong>Country</strong>: ' + str(name).capitalize() + '<br>'
                                '<strong>Confirmed Cases</strong>: ' + str(value) + '<br>'),
                        color='red',
                        fill=True,
                        fill_color='red',
                        fill_opacity=0.3 ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
